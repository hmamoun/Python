# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
# Requirement already satisfied: requests>=2.18.4 in c:\users\hmamo\anaconda3\lib\site-packages (from chembl_webresource_client) (2.25.1)
# Requirement already satisfied: urllib3 in c:\users\hmamo\anaconda3\lib\site-packages (from chembl_webresource_client) (1.26.4)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.4-py3-none-any.whl (38 kB)
# Collecting easydict
#   Downloading easydict-1.9.tar.gz (6.4 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hmamo\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hmamo\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hmamo\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\hmamo\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (5.4.1)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting attrs<22.0,>=21.2
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in c:\users\hmamo\anaconda3\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py): started
#   Building wheel for easydict (setup.py): finished with status 'done'
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6350 sha256=f078e6b1b4a34d1d62089943b739b7d4a9ccd12bf7690d911b52315fbf371f9a
#   Stored in directory: c:\users\hmamo\appdata\local\pip\cache\wheels\d3\e0\e9\305e348717e399665119bd012510d51ff4f22d709ff60c3096
# Successfully built easydict
# Installing collected packages: url-normalize, itsdangerous, attrs, requests-cache, easydict, chembl-webresource-client
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
# Successfully installed attrs-21.2.0 chembl-webresource-client-0.10.7 easydict-1.9 itsdangerous-2.0.1 requests-cache-0.7.4 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
#target_query = target.search('acetylcholinesterase')
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   15.0
# 2                                 Feline coronavirus   15.0
# 3                             Human coronavirus 229E   13.0
# 4                SARS coronavirus 3C-like proteinase   10.0
# 5  Middle East respiratory syndrome-related coron...    9.0
# 6                          Replicase polyprotein 1ab    4.0
# 7                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False     CHEMBL613837
# 4               False       CHEMBL3927
# 5               False    CHEMBL4296578
# 6               False       CHEMBL5118
# 7               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM    11137
# 4  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 5                                                 []        ORGANISM  1335626
# 6  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 7  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1480935                  []    CHEMBL829584
# 1             None      1480936                  []    CHEMBL829584
# 2             None      1481061                  []    CHEMBL830868
#
#                                    assay_description assay_type  \
# 0  In vitro inhibitory concentration against SARS...          B
# 1  In vitro inhibitory concentration against SARS...          B
# 2  In vitro inhibitory concentration against SARS...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ...   target_organism                     target_pref_name target_tax_id  \
# 0  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#   text_value  toid  type  units    uo_units upper_value value
# 0       None  None  IC50     uM  UO_0000065        None   7.2
# 1       None  None  IC50     uM  UO_0000065        None   9.4
# 2       None  None  IC50     uM  UO_0000065        None  13.5
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
df.describe(include='all').T
# Out:
#                            count unique  \
# activity_comment               0      0
# activity_id                133.0    NaN
# activity_properties          133      1
# assay_chembl_id              133     12
# assay_description            133     11
# assay_type                   133      1
# assay_variant_accession        0      0
# assay_variant_mutation         0      0
# bao_endpoint                 133      1
# bao_format                   133      2
# bao_label                    133      2
# canonical_smiles             133     86
# data_validity_comment         42      1
# data_validity_description     42      1
# document_chembl_id           133      7
# document_journal             133      3
# document_year              133.0    NaN
# ligand_efficiency             91     91
# molecule_chembl_id           133     86
# molecule_pref_name            26      7
# parent_molecule_chembl_id    133     86
# pchembl_value                 91     66
# potential_duplicate          133      1
# qudt_units                   133      1
# record_id                  133.0    NaN
# relation                     133      3
# src_id                     133.0    NaN
# standard_flag                133      1
# standard_relation            133      3
# standard_text_value            0      0
# standard_type                133      1
# standard_units               133      1
# standard_upper_value           0      0
# standard_value               133     96
# target_chembl_id             133      1
# target_organism              133      1
# target_pref_name             133      1
# target_tax_id                133      1
# text_value                     0      0
# toid                           0      0
# type                         133      2
# units                        105      2
# uo_units                     133      1
# upper_value                    0      0
# value                        133     91
#
#                                                                          top  \
# activity_comment                                                         NaN
# activity_id                                                              NaN
# activity_properties                                                       []
# assay_chembl_id                                                 CHEMBL871248
# assay_description            Inhibition of SARS coronavirus 3C-like protease
# assay_type                                                                 B
# assay_variant_accession                                                  NaN
# assay_variant_mutation                                                   NaN
# bao_endpoint                                                     BAO_0000190
# bao_format                                                       BAO_0000357
# bao_label                                              single protein format
# canonical_smiles                      Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# data_validity_comment                                  Outside typical range
# data_validity_description  Values for this activity type are unusually la...
# document_chembl_id                                             CHEMBL1148632
# document_journal                                               J. Med. Chem.
# document_year                                                            NaN
# ligand_efficiency          {'bei': '7.44', 'le': '0.14', 'lle': '1.35', '...
# molecule_chembl_id                                              CHEMBL227075
# molecule_pref_name                                       DIHYDROTANSHINONE I
# parent_molecule_chembl_id                                       CHEMBL215254
# pchembl_value                                                           4.82
# potential_duplicate                                                    False
# qudt_units                         http://www.openphacts.org/units/Nanomolar
# record_id                                                                NaN
# relation                                                                   =
# src_id                                                                   NaN
# standard_flag                                                           True
# standard_relation                                                          =
# standard_text_value                                                      NaN
# standard_type                                                           IC50
# standard_units                                                            nM
# standard_upper_value                                                     NaN
# standard_value                                                       15000.0
# target_chembl_id                                                  CHEMBL3927
# target_organism                                             SARS coronavirus
# target_pref_name                         SARS coronavirus 3C-like proteinase
# target_tax_id                                                         227859
# text_value                                                               NaN
# toid                                                                     NaN
# type                                                                    IC50
# units                                                                     uM
# uo_units                                                          UO_0000065
# upper_value                                                              NaN
# value                                                                   3.69
#
#                           freq            mean             std        min  \
# activity_comment           NaN             NaN             NaN        NaN
# activity_id                NaN  3726206.007519  4114943.110507  1480935.0
# activity_properties        133             NaN             NaN        NaN
# assay_chembl_id             56             NaN             NaN        NaN
# assay_description           64             NaN             NaN        NaN
# assay_type                 133             NaN             NaN        NaN
# assay_variant_accession    NaN             NaN             NaN        NaN
# assay_variant_mutation     NaN             NaN             NaN        NaN
# bao_endpoint               133             NaN             NaN        NaN
# bao_format                 107             NaN             NaN        NaN
# bao_label                  107             NaN             NaN        NaN
# canonical_smiles             4             NaN             NaN        NaN
# data_validity_comment       42             NaN             NaN        NaN
# data_validity_description   42             NaN             NaN        NaN
# document_chembl_id          56             NaN             NaN        NaN
# document_journal            95             NaN             NaN        NaN
# document_year              NaN      2007.12782        2.444578     2005.0
# ligand_efficiency            1             NaN             NaN        NaN
# molecule_chembl_id           4             NaN             NaN        NaN
# molecule_pref_name           4             NaN             NaN        NaN
# parent_molecule_chembl_id    4             NaN             NaN        NaN
# pchembl_value                5             NaN             NaN        NaN
# potential_duplicate        133             NaN             NaN        NaN
# qudt_units                 133             NaN             NaN        NaN
# record_id                  NaN   737266.616541   492464.988909   383984.0
# relation                   131             NaN             NaN        NaN
# src_id                     NaN             1.0             0.0        1.0
# standard_flag              133             NaN             NaN        NaN
# standard_relation          131             NaN             NaN        NaN
# standard_text_value        NaN             NaN             NaN        NaN
# standard_type              133             NaN             NaN        NaN
# standard_units             133             NaN             NaN        NaN
# standard_upper_value       NaN             NaN             NaN        NaN
# standard_value               5             NaN             NaN        NaN
# target_chembl_id           133             NaN             NaN        NaN
# target_organism            133             NaN             NaN        NaN
# target_pref_name           133             NaN             NaN        NaN
# target_tax_id              133             NaN             NaN        NaN
# text_value                 NaN             NaN             NaN        NaN
# toid                       NaN             NaN             NaN        NaN
# type                       105             NaN             NaN        NaN
# units                       97             NaN             NaN        NaN
# uo_units                   133             NaN             NaN        NaN
# upper_value                NaN             NaN             NaN        NaN
# value                        5             NaN             NaN        NaN
#
#                                  25%        50%        75%         max
# activity_comment                 NaN        NaN        NaN         NaN
# activity_id                1720632.0  1720665.0  1830967.0  12041511.0
# activity_properties              NaN        NaN        NaN         NaN
# assay_chembl_id                  NaN        NaN        NaN         NaN
# assay_description                NaN        NaN        NaN         NaN
# assay_type                       NaN        NaN        NaN         NaN
# assay_variant_accession          NaN        NaN        NaN         NaN
# assay_variant_mutation           NaN        NaN        NaN         NaN
# bao_endpoint                     NaN        NaN        NaN         NaN
# bao_format                       NaN        NaN        NaN         NaN
# bao_label                        NaN        NaN        NaN         NaN
# canonical_smiles                 NaN        NaN        NaN         NaN
# data_validity_comment            NaN        NaN        NaN         NaN
# data_validity_description        NaN        NaN        NaN         NaN
# document_chembl_id               NaN        NaN        NaN         NaN
# document_journal                 NaN        NaN        NaN         NaN
# document_year                 2006.0     2006.0     2007.0      2012.0
# ligand_efficiency                NaN        NaN        NaN         NaN
# molecule_chembl_id               NaN        NaN        NaN         NaN
# molecule_pref_name               NaN        NaN        NaN         NaN
# parent_molecule_chembl_id        NaN        NaN        NaN         NaN
# pchembl_value                    NaN        NaN        NaN         NaN
# potential_duplicate              NaN        NaN        NaN         NaN
# qudt_units                       NaN        NaN        NaN         NaN
# record_id                   491915.0   491932.0   629355.0   1727230.0
# relation                         NaN        NaN        NaN         NaN
# src_id                           1.0        1.0        1.0         1.0
# standard_flag                    NaN        NaN        NaN         NaN
# standard_relation                NaN        NaN        NaN         NaN
# standard_text_value              NaN        NaN        NaN         NaN
# standard_type                    NaN        NaN        NaN         NaN
# standard_units                   NaN        NaN        NaN         NaN
# standard_upper_value             NaN        NaN        NaN         NaN
# standard_value                   NaN        NaN        NaN         NaN
# target_chembl_id                 NaN        NaN        NaN         NaN
# target_organism                  NaN        NaN        NaN         NaN
# target_pref_name                 NaN        NaN        NaN         NaN
# target_tax_id                    NaN        NaN        NaN         NaN
# text_value                       NaN        NaN        NaN         NaN
# toid                             NaN        NaN        NaN         NaN
# type                             NaN        NaN        NaN         NaN
# units                            NaN        NaN        NaN         NaN
# uo_units                         NaN        NaN        NaN         NaN
# upper_value                      NaN        NaN        NaN         NaN
# value                            NaN        NaN        NaN         NaN

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
! mkdir data
! copy bioactivity_data.csv "data/"
# Out:
# A subdirectory or file data already exists.
#         1 file(s) copied.

# %%
ls data\
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is A69D-2A80
#
#  Directory of C:\Users\hmamo\Python\Drug Discovery\python-main\data
#
# 09/06/2021  01:02 PM    <DIR>          .
# 09/06/2021  01:02 PM    <DIR>          ..
# 09/06/2021  12:07 PM            70,468 bioactivity_data.csv
#                1 File(s)         70,468 bytes
#                2 Dir(s)  160,858,083,328 bytes free

# %%
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# 0    In vitro inhibitory concentration against SARS...          B
# 1    In vitro inhibitory concentration against SARS...          B
# 2    In vitro inhibitory concentration against SARS...          B
# 3    In vitro inhibitory concentration against SARS...          B
# 4    In vitro inhibitory concentration against SARS...          B
# ..                                                 ...        ...
# 128  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 129  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 130  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 131  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 132  Inhibition of SARS-CoV PLpro expressed in Esch...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000357
# 1                      None                   None  BAO_0000190  BAO_0000357
# 2                      None                   None  BAO_0000190  BAO_0000357
# 3                      None                   None  BAO_0000190  BAO_0000357
# 4                      None                   None  BAO_0000190  BAO_0000357
# ..                      ...                    ...          ...          ...
# 128                    None                   None  BAO_0000190  BAO_0000019
# 129                    None                   None  BAO_0000190  BAO_0000019
# 130                    None                   None  BAO_0000190  BAO_0000019
# 131                    None                   None  BAO_0000190  BAO_0000019
# 132                    None                   None  BAO_0000190  BAO_0000019
#
#      ...   target_organism                     target_pref_name target_tax_id  \
# 0    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..   ...               ...                                  ...           ...
# 128  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 129  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 130  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 131  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 132  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#     text_value  toid  type  units    uo_units upper_value  value
# 0         None  None  IC50     uM  UO_0000065        None    7.2
# 1         None  None  IC50     uM  UO_0000065        None    9.4
# 2         None  None  IC50     uM  UO_0000065        None   13.5
# 3         None  None  IC50     uM  UO_0000065        None  13.11
# 4         None  None  IC50     uM  UO_0000065        None    2.0
# ..         ...   ...   ...    ...         ...         ...    ...
# 128       None  None  IC50     uM  UO_0000065        None   10.6
# 129       None  None  IC50     uM  UO_0000065        None   10.1
# 130       None  None  IC50     uM  UO_0000065        None   11.5
# 131       None  None  IC50     uM  UO_0000065        None   10.7
# 132       None  None  IC50     uM  UO_0000065        None   78.9
#
# [133 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 86

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 109             None     12040781                  []   CHEMBL2149727
# 110             None     12040782                  []   CHEMBL2149727
# 111             None     12040783                  []   CHEMBL2149727
# 112             None     12040784                  []   CHEMBL2149727
# 113             None     12040785                  []   CHEMBL2149727
#
#                                      assay_description assay_type  \
# 0    In vitro inhibitory concentration against SARS...          B
# 1    In vitro inhibitory concentration against SARS...          B
# 2    In vitro inhibitory concentration against SARS...          B
# 3    In vitro inhibitory concentration against SARS...          B
# 4    In vitro inhibitory concentration against SARS...          B
# ..                                                 ...        ...
# 109  Inhibition of SARS-CoV 3CLpro expressed in Esc...          B
# 110  Inhibition of SARS-CoV 3CLpro expressed in Esc...          B
# 111  Inhibition of SARS-CoV 3CLpro expressed in Esc...          B
# 112  Inhibition of SARS-CoV 3CLpro expressed in Esc...          B
# 113  Inhibition of SARS-CoV 3CLpro expressed in Esc...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000357
# 1                      None                   None  BAO_0000190  BAO_0000357
# 2                      None                   None  BAO_0000190  BAO_0000357
# 3                      None                   None  BAO_0000190  BAO_0000357
# 4                      None                   None  BAO_0000190  BAO_0000357
# ..                      ...                    ...          ...          ...
# 109                    None                   None  BAO_0000190  BAO_0000019
# 110                    None                   None  BAO_0000190  BAO_0000019
# 111                    None                   None  BAO_0000190  BAO_0000019
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
#
#      ...   target_organism                     target_pref_name target_tax_id  \
# 0    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4    ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..   ...               ...                                  ...           ...
# 109  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 110  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 111  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 112  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 113  ...  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#     text_value  toid  type  units    uo_units upper_value  value
# 0         None  None  IC50     uM  UO_0000065        None    7.2
# 1         None  None  IC50     uM  UO_0000065        None    9.4
# 2         None  None  IC50     uM  UO_0000065        None   13.5
# 3         None  None  IC50     uM  UO_0000065        None  13.11
# 4         None  None  IC50     uM  UO_0000065        None    2.0
# ..         ...   ...   ...    ...         ...         ...    ...
# 109       None  None  IC50     uM  UO_0000065        None   21.1
# 110       None  None  IC50     uM  UO_0000065        None  226.7
# 111       None  None  IC50     uM  UO_0000065        None   38.7
# 112       None  None  IC50     uM  UO_0000065        None   14.4
# 113       None  None  IC50     uM  UO_0000065        None   21.1
#
# [86 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 109      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 110       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 111       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 112       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 113        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# 2          13500.0
# 3          13110.0
# 4           2000.0
# ..             ...
# 109        21100.0
# 110       226700.0
# 111        38700.0
# 112        14400.0
# 113        21100.0
#
# [86 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1        CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2        CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3        CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4        CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                ...                                                ...
# 81      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 82       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 83       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 84       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 85        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value         class
# 0           7200.0  intermediate
# 1           9400.0  intermediate
# 2          13500.0      inactive
# 3          13110.0      inactive
# 4           2000.0  intermediate
# ..             ...           ...
# 81         21100.0      inactive
# 82        226700.0      inactive
# 83         38700.0      inactive
# 84         14400.0      inactive
# 85         21100.0      inactive
#
# [86 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! ls -l
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ---
